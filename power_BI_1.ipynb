# %% [markdown]
# **Question 1-What is Power BI and why is it used in businesses?**
# - Power BI is the business intelligence which is used to create visualization with the help of raw data and get meaningful insights in business.
#
# **Question 2 : Name and explain the three main components of Power BI.**
# - The three main compnents of power BI are:-
# 1. Power BI desktop
# 2. Power BI service
# 3. Power BI MObile
# # Power BI Desktop
# It is an windows application which used to create dashboards and reports.
#
# # Power BI Service
#
# It is a cloud based online plattform when we want to publish our dashboard or reports we wiil use this component of Power BI.
#
# # Power BI MObile
#
# It is mobile application when we want to see dashboards and reports in our mobile we will use this component.
#
# **Question 3 : Explain the Power BI workflow.**
# ## Workflow of Power BI
#
# - Connect to raw data
# -  Transform and clean data
# - Create data model
# - Create Reports and Visualization
# - Pulish to Power BI service
# - Share and Collaborate.
#
# **Question 4 : List any four data cleaning tasks that can be performed in Power Query.**
# - Removal of Duplicates values
# - Filtering the rows
# - Changing the type of data
# - Handle missing values.
#
# **Question 5 : Write step by step instructions to load the above dataset.**
# - step1- Open Powe BI desktop.
# - Step 2- On the home tab click on **Get Data.**
# - Step3- Select the data source for example:
#
# Excel
#
# Text
#
# SQL server
#
# - Step4- select the dataset and click open
# - Step 5- Preview the data
# - Step6- Transform the data if you want to delete any row or column or a row or any edition in your data.
# - Step7- Once the editing is done click the on load to import the data into power BI.
#
# **Question 6 : Define Data View, Report View, and Model View. Explain the purpose of each view.**
# - Data view is used to show the data in table format and is used to create calculated columns. Report view is used to create visualization and design reports. Model view displays relationship between tables and helps the manage the data model.
#
# **Question 7 : Discuss the different data sources that Power BI supports.**
# ## File based sources
# - Excel
# - CSV
# - Text files
#
# ## Database sources
# - SQL server
# - MYSQL
# - Microsoft access
#
# ## Cloud based sources
# - Dynamic 365
# - Google analytics
#
# ## Web and API Sources
#  - web pages url
#
#  **Question 8 : Split Owner Name to create two new columns as First Name and Last Name**
#  - Step1- In home tab, click on transform data.
#  - Step 2- Selec the Owner Name column.
#  - Step3- In transform tab, Clickon split column.
#  - Step 4- Choose by Delimiter.
#  - Step 5- Select Space as the delimeter
#  - Step 6- Choose split at left most delimeter
#  -  Step 7- click ok
#  - Step 8- Rename the column as: first name and last name.
#  - step 9- Click close & apply.
